# %% [markdown]
# ## ESCUELA POLITÉCNICA NACIONAL
# ## MÉTODOS NUMÉRICOS
# ## TALLER METODO DE EULER
# ### Aubertin Ochoa
# ### 05/02/2025

# %%
from src import ODE_euler

ys, ts, h = ODE_euler(a=0, b=2.0, f=lambda t, y: y - t**2 + 1, y_t0=0.5, N=10)
print(ys, ts, h)
# Out:
# [0.5, 0.8, 1.1520000000000001, 1.5504000000000002, 1.9884800000000002, 2.4581760000000004, 2.9498112000000005, 3.4517734400000006, 3.950128128000001, 4.428153753600001, 4.865784504320001] [0, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0, 1.2, 1.4, 1.5999999999999999, 1.7999999999999998, 1.9999999999999998] 0.2

# %%
import matplotlib.pyplot as plt

# Definir la función analítica
def solucion_analitica(t):
    return (t + 1)**2 - 0.5 * np.exp(t)

# Calcular la solución analítica en los puntos ts
ys_analitica = [solucion_analitica(t) for t in ts]

# Graficar los resultados
plt.plot(ts, ys, 'o-', label='Método de Euler')
plt.plot(ts, ys_analitica, 'x-', label='Funcion REAL')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Solución ODE usando el método de Euler vs Solución Analítica')
plt.legend()
plt.grid(True)
plt.show()

# %%
from src import ODE_euler
#N=5
ys5, ts5, h5 = ODE_euler(a=0, b=2.0, f=lambda t, y: y - t**2 + 1, y_t0=0.5, N=5)
print(ys5, ts5, h5)


#N=20
ys20, ts20, h20 = ODE_euler(a=0, b=2.0, f=lambda t, y: y - t**2 + 1, y_t0=0.5, N=20)
print(ys20, ts20, h20)
# Out:
# [0.5, 1.1, 1.8760000000000001, 2.7704, 3.70256, 4.559584] [0, 0.4, 0.8, 1.2000000000000002, 1.6, 2.0] 0.4
# [0.5, 0.65, 0.8140000000000001, 0.9914000000000001, 1.18154, 1.383694, 1.5970634000000001, 1.8207697400000002, 2.053846714, 2.2952313854, 2.54375452394, 2.798129976334, 3.0569429739674003, 3.3186372713641403, 3.5815009985005544, 3.84365109835061, 4.103016208185671, 4.357317829004238, 4.604049611904662, 4.840454573095128, 5.063500030404641] [0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6, 0.7, 0.7999999999999999, 0.8999999999999999, 0.9999999999999999, 1.0999999999999999, 1.2, 1.3, 1.4000000000000001, 1.5000000000000002, 1.6000000000000003, 1.7000000000000004, 1.8000000000000005, 1.9000000000000006, 2.0000000000000004] 0.1

# %%
import matplotlib.pyplot as plt

# Definir la función analítica
def solucion_analitica(t):
    return (t + 1)**2 - 0.5 * np.exp(t)

# Calcular la solución analítica en los puntos ts
ys_analitica = [solucion_analitica(t) for t in ts]

# Graficar los resultados
plt.plot(ts5, ys5, 'o-', label='Método de Euler N=5')
plt.plot(ts20, ys20, 'o-', label='Método de Euler N=20')
plt.plot(ts, ys, 'o-', label='Método de Euler N=10')
plt.plot(ts, ys_analitica, 'x-', label='Funcion REAL')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Solución ODE usando el método de Euler vs Solución Analítica')
plt.legend()
plt.grid(True)
plt.show()

# %%
from src import ODE_euler
#N=3
ys30, ts30, h30 = ODE_euler(a=1.0, b=2.0, f=lambda t, y: y/t - (y/t)**2, y_t0=1, N=30)
print(ys30, ts30, h30)
# Out:
# [1, 1.0, 1.0010405827263267, 1.002965222569384, 1.0056462833722122, 1.0089786711030468, 1.0128750912878473, 1.0172624560793762, 1.0220791279117192, 1.027272780646665, 1.032798722441204, 1.0386185679820557, 1.0446991779728656, 1.0510118051277098, 1.0575314012255774, 1.064236050872572, 1.0711065057515647, 1.078125799165871, 1.085278925193931, 1.0925525701788295, 1.099934886872137, 1.1074153035452787, 1.1149843619247561, 1.1226335790105493, 1.13035532878125, 1.1381427405353866, 1.145989611211236, 1.153890329501321, 1.1618398099587157, 1.169833435600053, 1.1778670077600555] [1.0, 1.0333333333333334, 1.0666666666666669, 1.1000000000000003, 1.1333333333333337, 1.1666666666666672, 1.2000000000000006, 1.233333333333334, 1.2666666666666675, 1.300000000000001, 1.3333333333333344, 1.3666666666666678, 1.4000000000000012, 1.4333333333333347, 1.4666666666666681, 1.5000000000000016, 1.533333333333335, 1.5666666666666684, 1.6000000000000019, 1.6333333333333353, 1.6666666666666687, 1.7000000000000022
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definir la función analítica
def solReal(t):
    return t/(1 + np.log(t))


tContinuo = np.linspace(a, b, 100)
yContinuo = solReal(tContinuo)

plt.plot(ts30, ys30, 'o-', label='Método de Euler N=3')
plt.plot(tContinuo, yContinuo, '-', label='Funcion REAL')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Solución ODE usando el método de Euler vs Solución Analítica')
plt.legend()
plt.grid(True)
plt.show()

# %%
from src import ODE_euler
#N=3
ys3, ts3, h3 = ODE_euler(a=1.0, b=2.0, f=lambda t, y: y/t - (y/t)**2, y_t0=1, N=3)
print(ys3, ts3, h3)

#N=8
ys8, ts8, h8 = ODE_euler(a=1.0, b=2.0, f=lambda t, y: y/t - (y/t)**2, y_t0=1, N=8)
print(ys8, ts8, h8)
# Out:
# [1, 1.0, 1.0625, 1.13953125] [1.0, 1.3333333333333333, 1.6666666666666665, 1.9999999999999998] 0.3333333333333333
# [1, 1.0, 1.0123456790123457, 1.0315927450083828, 1.0550146579229347, 1.081096105614721, 1.1089310112738267, 1.1379473901295167, 1.1677687979087261] [1.0, 1.125, 1.25, 1.375, 1.5, 1.625, 1.75, 1.875, 2.0] 0.125

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definir la función analítica
def solReal(t):
    return t/(1 + np.log(t))

tContinuo = np.linspace(a, b, 100)
yContinuo = solReal(tContinuo)

plt.plot(ts3, ys3, 'o-', label='Método de Euler N=3')
plt.plot(ts8, ys8, 'o-', label='Método de Euler N=8')
plt.plot(tContinuo, yContinuo, '-', label='Funcion REAL')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Solución ODE usando el método de Euler vs Solución Analítica')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## **¿Qué pasa al aumentar N?**
#
# La solucion es mas aproximada a la solución real.
